# %% [markdown]
# # Medicare Part D Data Cleaning and Feature Engineering
# Data Source: Data Source: https://data.cms.gov/Medicare-Part-D/Medicare-Provider-Utilization-and-Payment-Data-201/yvpj-pmj2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer

# %%
# setting styles for plotting
plt.rcParams['figure.figsize'] = [20, 5]
plt.rcParams['image.cmap'] = 'bone'
sns.set_palette('bone')
sns.set_style('whitegrid')
sns.set_context('poster')

# %%
# read in medicare state drug utilization data
drugs2016 = pd.read_csv('Medicare_Provider_Utilization_and_Payment_Data__2016_Part_D_Prescriber.csv')
print(drugs2016.shape)
drugs2016.head()
# Out:
# (24964300, 21)
#           npi nppes_provider_last_org_name nppes_provider_first_name  \
# 0  1003000126                    ENKESHAFI                   ARDALAN
# 1  1003000126                    ENKESHAFI                   ARDALAN
# 2  1003000126                    ENKESHAFI                   ARDALAN
# 3  1003000126                    ENKESHAFI                   ARDALAN
# 4  1003000126                    ENKESHAFI                   ARDALAN
#
#   nppes_provider_city nppes_provider_state specialty_description  \
# 0          CUMBERLAND                   MD     Internal Medicine
# 1          CUMBERLAND                   MD     Internal Medicine
# 2          CUMBERLAND                   MD     Internal Medicine
# 3          CUMBERLAND                   MD     Internal Medicine
# 4          CUMBERLAND                   MD     Internal Medicine
#
#   description_flag             drug_name          generic_name  bene_count  \
# 0                S  ATORVASTATIN CALCIUM  ATORVASTATIN CALCIUM         NaN
# 1                S     CIPROFLOXACIN HCL     CIPROFLOXACIN HCL         NaN
# 2                S   DOXYCYCLINE HYCLATE   DOXYCYCLINE HYCLATE        20.0
# 3                S               ELIQUIS              APIXABAN         NaN
# 4                S            FUROSEMIDE            FUROSEMIDE        12.0
#
#            ...           total_30_day_fill_count  total_day_supply  \
# 0          ...                              15.0               450
# 1          ...                              11.0                96
# 2          ...                              20.0               199
# 3          ...                              17.0               510
# 4          ...                              17.0               405
#
#    total_drug_cost  bene_count_ge65  bene_count_ge65_suppress_flag  \
# 0           139.32              NaN                              *
# 1            80.99              NaN                              *
# 2           586.12              NaN                              #
# 3          6065.02              NaN                              *
# 4            45.76              NaN                              #
#
#   total_claim_count_ge65  ge65_suppress_flag total_30_day_fill_count_ge65  \
# 0                   13.0                 NaN                         15.0
# 1                    NaN                   *                          NaN
# 2                    NaN                   #                          NaN
# 3                   17.0                 NaN                         17.0
# 4                    NaN                   #                          NaN
#
#    total_day_supply_ge65  total_drug_cost_ge65
# 0                  450.0                139.32
# 1                    NaN                   NaN
# 2                    NaN                   NaN
# 3                  510.0               6065.02
# 4                    NaN                   NaN
#
# [5 rows x 21 columns]

# %%
drugs2016.columns
# Out:
# Index(['npi', 'nppes_provider_last_org_name', 'nppes_provider_first_name',
#        'nppes_provider_city', 'nppes_provider_state', 'specialty_description',
#        'description_flag', 'drug_name', 'generic_name', 'bene_count',
#        'total_claim_count', 'total_30_day_fill_count', 'total_day_supply',
#        'total_drug_cost', 'bene_count_ge65', 'bene_count_ge65_suppress_flag',
#        'total_claim_count_ge65', 'ge65_suppress_flag',
#        'total_30_day_fill_count_ge65', 'total_day_supply_ge65',
#        'total_drug_cost_ge65'],
#       dtype='object')

# %%
# read in drug info
druglist = pd.read_excel('20180208_HEDIS 2018_NDC_MLD_Directory_Complete_Workbook.xlsx',
                         'Medications List to NDC Codes')
druglist.head()
# Out:
#       Medication List   NDC Code   Brand Name  \
# 0  5-ARI Medications    54039513  Dutasteride
# 1  5-ARI Medications    54039522  Dutasteride
# 2  5-ARI Medications    93565556  Dutasteride
# 3  5-ARI Medications    93565598  Dutasteride
# 4  5-ARI Medications   115143808  Dutasteride
#
#               Generic Product Name Route        Description Drug ID Drug Name  \
# 0  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 1  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 2  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 3  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 4  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
#
#    Package Size Unit  Dose Form  MED Conversion Factor
# 0           NaN  NaN   NaN  NaN                    NaN
# 1           NaN  NaN   NaN  NaN                    NaN
# 2           NaN  NaN   NaN  NaN                    NaN
# 3           NaN  NaN   NaN  NaN                    NaN
# 4           NaN  NaN   NaN  NaN                    NaN

# %%
# new dataframe with only opioid drugs
# we can tell if a drug is an opioid if the MED (Morphine Equivalent Dose) is not nan
opioiddrugs = druglist[druglist['MED Conversion Factor'].notnull()].copy()
opioiddrugs['Drug Name'] = opioiddrugs['Drug Name'].str.upper()
opioiddrugs.head()
# Out:
#           Medication List     NDC Code                        Brand Name  \
# 52293  Opioid Medications    591264101  APAP/Butalbital/Caffeine/Codeine
# 52294  Opioid Medications  52544008201             Fioricet with Codeine
# 52295  Opioid Medications    143300001  APAP/Butalbital/Caffeine/Codeine
# 52296  Opioid Medications    247084530             Fioricet with Codeine
# 52297  Opioid Medications    591322001  APAP/Butalbital/Caffeine/Codeine
#
#                                     Generic Product Name Route  \
# 52293  acetaminophen/butalbital/caffeine/codeine 300 ...  oral
# 52294  acetaminophen/butalbital/caffeine/codeine 300 ...  oral
# 52295  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
# 52296  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
# 52297  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
#
#               Description Drug ID Drug Name  Package Size Unit  Dose Form  \
# 52293  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52294  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52295  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52296  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52297  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
#
#        MED Conversion Factor
# 52293                   0.15
# 52294                   0.15
# 52295                   0.15
# 52296                   0.15
# 52297                   0.15

# %%
opioiddrugs['Drug Name'].unique()
# Out:
# array(['CODEINE', 'DIHYDROCODEINE', 'HYDROCODONE', 'OXYCODONE',
#        'PENTAZOCINE', 'TRAMADOL', 'OPIUM', 'BUPRENORPHINE', 'BUTORPHANOL',
#        'FENTANYL', 'HYDROMORPHONE', 'LEVORPHANOL', 'MEPERIDINE',
#        'METHADONE', 'MORPHINE', 'MORPHINE EQUIVALENT', 'OXYMORPHONE',
#        'TAPENTADOL'], dtype=object)

# %%
## convert drug name column to list
opioids = opioiddrugs['Drug Name'].unique().tolist()
## join list of strings to create regex
opioids = '|'.join(opioids)
## use str.contains to match pattern
opioids_ = drugs2016[(drugs2016['drug_name'].str.contains(opioids)) | (drugs2016['generic_name'].str.contains(opioids))]

# %%
opioids
# Out:
# 'CODEINE|DIHYDROCODEINE|HYDROCODONE|OXYCODONE|PENTAZOCINE|TRAMADOL|OPIUM|BUPRENORPHINE|BUTORPHANOL|FENTANYL|HYDROMORPHONE|LEVORPHANOL|MEPERIDINE|METHADONE|MORPHINE|MORPHINE EQUIVALENT|OXYMORPHONE|TAPENTADOL'

# %%
def make_opioid_df(df):
    df = df[df['generic_name'].str.contains(opioids)].copy()
    return df

# %%
opioiddrugs2016 = make_opioid_df(drugs2016)

# %%
## there are asthma meds here!?
opioiddrugs2016.drug_name.unique()
# Out:
# array(['ACETAMINOPHEN-CODEINE', 'BUTRANS', 'FENTANYL',
#        'HYDROCODONE-ACETAMINOPHEN', 'MORPHINE SULFATE ER',
#        'OXYCODONE HCL', 'OXYCODONE-ACETAMINOPHEN', 'OXYCONTIN',
#        'TRAMADOL HCL', 'TRAMADOL HCL-ACETAMINOPHEN', 'MEPERIDINE HCL',
#        'SPIRIVA', 'METHADONE HCL', 'COMBIVENT RESPIMAT', 'MS CONTIN',
#        'VICODIN', 'LEVORPHANOL TARTRATE', 'IPRATROPIUM-ALBUTEROL',
#        'TRAMADOL HCL ER', 'SUBOXONE', 'STIOLTO RESPIMAT',
#        'HYDROMORPHONE HCL', 'SPIRIVA RESPIMAT', 'OXYMORPHONE HCL ER',
#        'NUCYNTA ER', 'IPRATROPIUM BROMIDE', 'OPANA ER',
#        'MORPHINE SULFATE', 'OXYCODONE HCL ER', 'PENTAZOCINE-NALOXONE HCL',
#        'EMBEDA', 'BUTORPHANOL TARTRATE', 'BUTALBITAL COMPOUND-CODEINE',
#        'DILAUDID', 'ULTRAM', 'ATROVENT HFA', 'BUPRENORPHINE HCL',
#        'CODEINE SULFATE', 'ENDOCET', 'KADIAN', 'OXYMORPHONE HCL',
#        'SUBSYS', 'ASCOMP WITH CODEINE', 'NUCYNTA', 'HYSINGLA ER',
#        'BUPRENORPHINE-NALOXONE', 'HYDROCODONE-IBUPROFEN',
#        'HYDROMORPHONE ER', 'DURAGESIC', 'ROXICODONE', 'ZOHYDRO ER',
#        'ZUBSOLV', 'EXALGO', 'VICODIN HP',
#        'BUTALB-CAFF-ACETAMINOPH-CODEIN', 'PERCOCET',
#        'OXYCODONE HCL-ASPIRIN', 'FENTORA', 'BELBUCA', 'DEMEROL',
#        'VICODIN ES', 'BUNAVAIL', 'NORCO', 'OPIUM TINCTURE',
#        'METHADONE INTENSOL', 'LORTAB', 'OPANA', 'ULTRACET',
#        'BUTALB-ACETAMINOPH-CAFF-CODEIN', 'FENTANYL CITRATE', 'APOKYN',
#        'BUPRENEX', 'FIORINAL WITH CODEINE #3', 'METHADOSE',
#        'FIORICET WITH CODEINE', 'ACTIQ', 'TYLENOL-CODEINE NO.3',
#        'PROMETHAZINE-CODEINE', 'PRIMLEV', 'XTAMPZA ER', 'XARTEMIS XR',
#        'DISKETS', 'TYLENOL-CODEINE NO.4', 'DOLOPHINE HCL', 'LAZANDA',
#        'CONZIP', 'IBUDONE', 'REPREXAIN', 'OXYCODONE HCL-IBUPROFEN',
#        'BELLADONNA-OPIUM', 'ABSTRAL', 'XODOL 10-300', 'HYDROMET',
#        'XODOL 7.5-300', 'SYNALGOS-DC', 'ATROVENT', 'ULTRAM ER',
#        'CARISOPRODOL-ASPIRIN-CODEINE', 'HYDROCODONE-HOMATROPINE MBR',
#        'DURAMORPH', 'CARISOPRODOL COMPOUND-CODEINE', 'INFUMORPH',
#        'ASPIRIN-CAFFEINE-DIHYDROCODEIN'], dtype=object)

# %%
# removing asthma drugs
asthmadrugs = ['COMBIVENT RESPIMAT', 'SPIRIVA RESPIMAT', 'ATROVENT', 'STIOLTO RESPIMAT', 'IPRATROPIUM BROMIDE', 'SPIRIVA', 'IPRATROPIUM-ALBUTEROL']

opioiddrugs2016 = opioiddrugs2016[~opioiddrugs2016.drug_name.isin(asthmadrugs)]

# %%
opioiddrugs2016.drug_name.unique()
# Out:
# array(['ACETAMINOPHEN-CODEINE', 'BUTRANS', 'FENTANYL',
#        'HYDROCODONE-ACETAMINOPHEN', 'MORPHINE SULFATE ER',
#        'OXYCODONE HCL', 'OXYCODONE-ACETAMINOPHEN', 'OXYCONTIN',
#        'TRAMADOL HCL', 'TRAMADOL HCL-ACETAMINOPHEN', 'MEPERIDINE HCL',
#        'METHADONE HCL', 'MS CONTIN', 'VICODIN', 'LEVORPHANOL TARTRATE',
#        'TRAMADOL HCL ER', 'SUBOXONE', 'HYDROMORPHONE HCL',
#        'OXYMORPHONE HCL ER', 'NUCYNTA ER', 'OPANA ER', 'MORPHINE SULFATE',
#        'OXYCODONE HCL ER', 'PENTAZOCINE-NALOXONE HCL', 'EMBEDA',
#        'BUTORPHANOL TARTRATE', 'BUTALBITAL COMPOUND-CODEINE', 'DILAUDID',
#        'ULTRAM', 'ATROVENT HFA', 'BUPRENORPHINE HCL', 'CODEINE SULFATE',
#        'ENDOCET', 'KADIAN', 'OXYMORPHONE HCL', 'SUBSYS',
#        'ASCOMP WITH CODEINE', 'NUCYNTA', 'HYSINGLA ER',
#        'BUPRENORPHINE-NALOXONE', 'HYDROCODONE-IBUPROFEN',
#        'HYDROMORPHONE ER', 'DURAGESIC', 'ROXICODONE', 'ZOHYDRO ER',
#        'ZUBSOLV', 'EXALGO', 'VICODIN HP',
#        'BUTALB-CAFF-ACETAMINOPH-CODEIN', 'PERCOCET',
#        'OXYCODONE HCL-ASPIRIN', 'FENTORA', 'BELBUCA', 'DEMEROL',
#        'VICODIN ES', 'BUNAVAIL', 'NORCO', 'OPIUM TINCTURE',
#        'METHADONE INTENSOL', 'LORTAB', 'OPANA', 'ULTRACET',
#        'BUTALB-ACETAMINOPH-CAFF-CODEIN', 'FENTANYL CITRATE', 'APOKYN',
#        'BUPRENEX', 'FIORINAL WITH CODEINE #3', 'METHADOSE',
#        'FIORICET WITH CODEINE', 'ACTIQ', 'TYLENOL-CODEINE NO.3',
#        'PROMETHAZINE-CODEINE', 'PRIMLEV', 'XTAMPZA ER', 'XARTEMIS XR',
#        'DISKETS', 'TYLENOL-CODEINE NO.4', 'DOLOPHINE HCL', 'LAZANDA',
#        'CONZIP', 'IBUDONE', 'REPREXAIN', 'OXYCODONE HCL-IBUPROFEN',
#        'BELLADONNA-OPIUM', 'ABSTRAL', 'XODOL 10-300', 'HYDROMET',
#        'XODOL 7.5-300', 'SYNALGOS-DC', 'ULTRAM ER',
#        'CARISOPRODOL-ASPIRIN-CODEINE', 'HYDROCODONE-HOMATROPINE MBR',
#        'DURAMORPH', 'CARISOPRODOL COMPOUND-CODEINE', 'INFUMORPH',
#        'ASPIRIN-CAFFEINE-DIHYDROCODEIN'], dtype=object)

# %%
opioiddrugs2016['year'] = 2016

# %%
opioiddrugs2016.sample(5)
# Out:
#                  npi nppes_provider_last_org_name nppes_provider_first_name  \
# 11089269  1972667434                      HERLIHY                   TIMOTHY
# 7377617   1073543427                       MAHLER                    EILEEN
# 10301566  1154399160                ORTIZ-CAMACHO                    HERNAN
# 23192173  1790892768                         BREY                     ROBIN
# 17665901  1790703734                     JUNTUNEN                  KRISTINE
#
#          nppes_provider_city nppes_provider_state specialty_description  \
# 11089269              TOWSON                   MD     Internal Medicine
# 7377617              CHICAGO                   IL    Nurse Practitioner
# 10301566              DORADO                   PR       Family Practice
# 23192173         SAN ANTONIO                   TX             Neurology
# 17665901            APPLETON                   WI     Internal Medicine
#
#          description_flag                  drug_name  \
# 11089269                S  HYDROCODONE-ACETAMINOPHEN
# 7377617                 S    OXYCODONE-ACETAMINOPHEN
# 10301566                S      ACETAMINOPHEN-CODEINE
# 23192173                S               TRAMADOL HCL
# 17665901                S              OXYCODONE HCL
#
#                          generic_name  bene_count  ...   total_day_supply  \
# 11089269    HYDROCODONE/ACETAMINOPHEN         NaN  ...               1053
# 7377617   OXYCODONE HCL/ACETAMINOPHEN        42.0  ...               3123
# 10301566   ACETAMINOPHEN WITH CODEINE        20.0  ...                222
# 23192173                 TRAMADOL HCL         NaN  ...                796
# 17665901                OXYCODONE HCL        12.0  ...                529
#
#           total_drug_cost  bene_count_ge65  bene_count_ge65_suppress_flag  \
# 11089269           499.67              NaN                              #
# 7377617          12967.27             16.0                            NaN
# 10301566           188.20              NaN                              #
# 23192173           312.61              NaN                              *
# 17665901           706.78              NaN                              *
#
#           total_claim_count_ge65 ge65_suppress_flag  \
# 11089269                     NaN                  #
# 7377617                     35.0                NaN
# 10301566                     NaN                  #
# 23192173                     NaN                  *
# 17665901                     NaN                  *
#
#           total_30_day_fill_count_ge65 total_day_supply_ge65  \
# 11089269                           NaN                   NaN
# 7377617                           35.0                 984.0
# 10301566                           NaN                   NaN
# 23192173                           NaN                   NaN
# 17665901                           NaN                   NaN
#
#           total_drug_cost_ge65  year
# 11089269                   NaN  2016
# 7377617                4172.85  2016
# 10301566                   NaN  2016
# 23192173                   NaN  2016
# 17665901                   NaN  2016
#
# [5 rows x 22 columns]

# %%
# saving cleaned dataframe to csv
opioiddrugs2016.to_csv('medicare_d_2016_opioids.csv')
