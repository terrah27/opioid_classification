# %% [markdown]
# # Medicaid Data Cleaning and Feature Engineering
#
# Data Source: https://data.medicaid.gov/State-Drug-Utilization/State-Drug-Utilization-Data-2016/3v6v-qk5s

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
from sklearn.preprocessing import StandardScaler
from sklearn.base import clone
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Imputer

# %%
# setting styles for plotting
plt.rcParams['figure.figsize'] = [20, 5]
plt.rcParams['image.cmap'] = 'bone'
sns.set_palette('bone')
sns.set_style('whitegrid')
sns.set_context('poster')

# %%
# read in 2016 medicaid state drug utilization data
drugs = pd.read_csv('sdued2016.csv')
print(drugs.shape)
drugs.head()
# Out:
# (4367625, 20)
#   utilizationtype state  labelercode  productcode  packagesize  year  quarter  \
# 0            FFSU    AK            2         1433           80  2016        1
# 1            FFSU    AK            2         1434           80  2016        1
# 2            FFSU    AK            2         3227           30  2016        1
# 3            FFSU    AK            2         3228           30  2016        1
# 4            FFSU    AK            2         3229           30  2016        1
#
#   productname  suppressionused  unitsreimbursed  numberofprescriptions  \
# 0   TRULICITY             True              NaN                    NaN
# 1   TRULICITY            False             32.0                   16.0
# 2   STRATTERA            False           1333.0                   40.0
# 3   STRATTERA            False           3175.0                   93.0
# 4   STRATTERA            False           3909.0                  122.0
#
#    totalamountreimbursed  medicaidamountreimbursed  \
# 0                    NaN                       NaN
# 1                8882.87                   8882.87
# 2               14311.75                  13192.79
# 3               34794.80                  32385.37
# 4               45969.37                  42022.86
#
#    nonmedicaidamountreimbursed quarterbegin quarterbegindate  latitude  \
# 0                          NaN          1/1       01/01/2016    61.385
# 1                         0.00          1/1       01/01/2016    61.385
# 2                      1118.96          1/1       01/01/2016    61.385
# 3                      2409.43          1/1       01/01/2016    61.385
# 4                      3946.51          1/1       01/01/2016    61.385
#
#    longitude             location      ndc
# 0  -152.2683  (61.385, -152.2683)  2143380
# 1  -152.2683  (61.385, -152.2683)  2143480
# 2  -152.2683  (61.385, -152.2683)  2322730
# 3  -152.2683  (61.385, -152.2683)  2322830
# 4  -152.2683  (61.385, -152.2683)  2322930

# %%
drugs.columns
# Out:
# Index(['utilizationtype', 'state', 'labelercode', 'productcode', 'packagesize',
#        'year', 'quarter', 'productname', 'suppressionused', 'unitsreimbursed',
#        'numberofprescriptions', 'totalamountreimbursed',
#        'medicaidamountreimbursed', 'nonmedicaidamountreimbursed',
#        'quarterbegin', 'quarterbegindate', 'latitude', 'longitude', 'location',
#        'ndc'],
#       dtype='object')

# %%
# checking for opioids
drugs.loc[drugs.productname.str.contains('HYDROM', na=False)].sample(5)
# Out:
#         utilizationtype state  labelercode  productcode  packagesize  year  \
# 815612             MCOU    GA          409         3365            1  2016
# 4134941            FFSU    WA          409         1283            5  2016
# 1317997            FFSU    IN          406         3244            1  2016
# 42532              FFSU    AL          527         1354            1  2016
# 1220272            MCOU    IN           54          265           25  2016
#
#          quarter productname  suppressionused  unitsreimbursed  \
# 815612         1  HYDROMORPH            False            152.0
# 4134941        4  HYDROMORPH            False            116.0
# 1317997        4  HYDROMORPH            False           2398.0
# 42532          1  HYDROMORPH            False           1226.0
# 1220272        1  HYDROMORPH            False           1800.0
#
#          numberofprescriptions  totalamountreimbursed  \
# 815612                    51.0                 196.11
# 4134941                   21.0                 350.55
# 1317997                   19.0                 315.24
# 42532                     12.0                 279.56
# 1220272                   14.0                1021.10
#
#          medicaidamountreimbursed  nonmedicaidamountreimbursed quarterbegin  \
# 815612                     195.56                         0.55          1/1
# 4134941                    350.55                         0.00         10/1
# 1317997                    276.24                        39.00         10/1
# 42532                      223.08                        56.48          1/1
# 1220272                   1017.10                         4.00          1/1
#
#         quarterbegindate  latitude  longitude              location        ndc
# 815612        01/01/2016   32.9866   -83.6487   (32.9866, -83.6487)  409336501
# 4134941       10/01/2016   47.3917  -121.5708  (47.3917, -121.5708)  409128305
# 1317997       10/01/2016   39.8647   -86.2604   (39.8647, -86.2604)  406324401
# 42532         01/01/2016   32.7990   -86.8073    (32.799, -86.8073)  527135401
# 1220272       01/01/2016   39.8647   -86.2604   (39.8647, -86.2604)   54026525

# %%
## testing to see if we have brand and generic named drugs...whch we do
drugs.loc[drugs.productname.str.contains('VICOD', na=False)].sample(5)
# Out:
#         utilizationtype state  labelercode  productcode  packagesize  year  \
# 2907329            FFSU    NY           74         3043           53  2016
# 2037969            MCOU    MN           74         3054           53  2016
# 1220867            MCOU    IN           74         3054           13  2016
# 3946877            MCOU    VA           74         3041           13  2016
# 2947141            FFSU    NY           74         3041           13  2016
#
#          quarter productname  suppressionused  unitsreimbursed  \
# 2907329        2  VICODIN TA             True              NaN
# 2037969        2  VICODIN HP             True              NaN
# 1220867        1  VICODIN TA             True              NaN
# 3946877        3  VICODIN TA            False           1033.0
# 2947141        3  VICODIN TA            False            710.0
#
#          numberofprescriptions  totalamountreimbursed  \
# 2907329                    NaN                    NaN
# 2037969                    NaN                    NaN
# 1220867                    NaN                    NaN
# 3946877                   37.0                1248.65
# 2947141                   19.0                 837.85
#
#          medicaidamountreimbursed  nonmedicaidamountreimbursed quarterbegin  \
# 2907329                       NaN                          NaN          4/1
# 2037969                       NaN                          NaN          4/1
# 1220867                       NaN                          NaN          1/1
# 3946877                   1248.65                         0.00          7/1
# 2947141                    664.01                       173.84          7/1
#
#         quarterbegindate  latitude  longitude             location       ndc
# 2907329       04/01/2016   42.1497   -74.9384  (42.1497, -74.9384)  74304353
# 2037969       04/01/2016   45.7326   -93.9196  (45.7326, -93.9196)  74305453
# 1220867       01/01/2016   39.8647   -86.2604  (39.8647, -86.2604)  74305413
# 3946877       07/01/2016   37.7680   -78.2057   (37.768, -78.2057)  74304113
# 2947141       07/01/2016   42.1497   -74.9384  (42.1497, -74.9384)  74304113

# %%
# replacing NaNs with 0
drugs = drugs.replace(np.nan, 0)
drugs.head()
# Out:
#   utilizationtype state  labelercode  productcode  packagesize  year  quarter  \
# 0            FFSU    AK            2         1433           80  2016        1
# 1            FFSU    AK            2         1434           80  2016        1
# 2            FFSU    AK            2         3227           30  2016        1
# 3            FFSU    AK            2         3228           30  2016        1
# 4            FFSU    AK            2         3229           30  2016        1
#
#   productname  suppressionused  unitsreimbursed  numberofprescriptions  \
# 0   TRULICITY             True              0.0                    0.0
# 1   TRULICITY            False             32.0                   16.0
# 2   STRATTERA            False           1333.0                   40.0
# 3   STRATTERA            False           3175.0                   93.0
# 4   STRATTERA            False           3909.0                  122.0
#
#    totalamountreimbursed  medicaidamountreimbursed  \
# 0                   0.00                      0.00
# 1                8882.87                   8882.87
# 2               14311.75                  13192.79
# 3               34794.80                  32385.37
# 4               45969.37                  42022.86
#
#    nonmedicaidamountreimbursed quarterbegin quarterbegindate  latitude  \
# 0                         0.00          1/1       01/01/2016    61.385
# 1                         0.00          1/1       01/01/2016    61.385
# 2                      1118.96          1/1       01/01/2016    61.385
# 3                      2409.43          1/1       01/01/2016    61.385
# 4                      3946.51          1/1       01/01/2016    61.385
#
#    longitude             location      ndc
# 0  -152.2683  (61.385, -152.2683)  2143380
# 1  -152.2683  (61.385, -152.2683)  2143480
# 2  -152.2683  (61.385, -152.2683)  2322730
# 3  -152.2683  (61.385, -152.2683)  2322830
# 4  -152.2683  (61.385, -152.2683)  2322930

# %%
# group by state and drug and get sums
drugs2 = drugs.groupby(['state', 'productname'])['unitsreimbursed'].sum()
drugs2 = pd.DataFrame(data=drugs2).reset_index()
drugs2.head()
# Out:
#   state productname  unitsreimbursed
# 0    AK  A-METHAPRE              0.0
# 1    AK    ABACAVIR           2024.0
# 2    AK  ABACAVIR-L              0.0
# 3    AK     ABILIFY           9579.0
# 4    AK  ABILIFY MA             98.0

# %%
drugs2['numberofprescriptions'] = drugs.groupby(['state', 'productname'])['numberofprescriptions'].sum().ravel()
drugs2['totalamountreimbursed'] = drugs.groupby(['state', 'productname'])['totalamountreimbursed'].sum().ravel()
drugs2['medicaidamountreimbursed'] = drugs.groupby(['state', 'productname'])['medicaidamountreimbursed'].sum().ravel()
drugs2['nonmedicaidamountreimbursed'] = drugs.groupby(['state', 'productname'])['nonmedicaidamountreimbursed'].sum().ravel()
drugs2.head()
# Out:
#   state productname  unitsreimbursed  numberofprescriptions  \
# 0    AK  A-METHAPRE              0.0                    0.0
# 1    AK    ABACAVIR           2024.0                   43.0
# 2    AK  ABACAVIR-L              0.0                    0.0
# 3    AK     ABILIFY           9579.0                  383.0
# 4    AK  ABILIFY MA             98.0                   98.0
#
#    totalamountreimbursed  medicaidamountreimbursed  \
# 0                   0.00                      0.00
# 1                6736.14                   6736.14
# 2                   0.00                      0.00
# 3              121183.60                 120565.62
# 4              165146.32                 165146.32
#
#    nonmedicaidamountreimbursed
# 0                         0.00
# 1                         0.00
# 2                         0.00
# 3                       617.98
# 4                         0.00

# %%
# read in drug info
druglist = pd.read_excel('20180208_HEDIS 2018_NDC_MLD_Directory_Complete_Workbook.xlsx',
                         'Medications List to NDC Codes')
druglist.head()
# Out:
#       Medication List   NDC Code   Brand Name  \
# 0  5-ARI Medications    54039513  Dutasteride
# 1  5-ARI Medications    54039522  Dutasteride
# 2  5-ARI Medications    93565556  Dutasteride
# 3  5-ARI Medications    93565598  Dutasteride
# 4  5-ARI Medications   115143808  Dutasteride
#
#               Generic Product Name Route        Description Drug ID Drug Name  \
# 0  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 1  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 2  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 3  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
# 4  dutasteride 0.5 mg oral capsule  oral  5-ARI Medications  d04788       NaN
#
#    Package Size Unit  Dose Form  MED Conversion Factor
# 0           NaN  NaN   NaN  NaN                    NaN
# 1           NaN  NaN   NaN  NaN                    NaN
# 2           NaN  NaN   NaN  NaN                    NaN
# 3           NaN  NaN   NaN  NaN                    NaN
# 4           NaN  NaN   NaN  NaN                    NaN

# %%
# new dataframe with only opioid drugs
# we can tell if a drug is an opioid if the MED (Morphine Equivalent Dose) is not nan
opioiddrugs = druglist[druglist['MED Conversion Factor'].notnull()].copy()
opioiddrugs['Drug Name'] = opioiddrugs['Drug Name'].str.upper()
opioiddrugs['Brand Name'] = opioiddrugs['Brand Name'].str.upper()
opioiddrugs.head()
# Out:
#           Medication List     NDC Code                        Brand Name  \
# 52293  Opioid Medications    591264101  APAP/BUTALBITAL/CAFFEINE/CODEINE
# 52294  Opioid Medications  52544008201             FIORICET WITH CODEINE
# 52295  Opioid Medications    143300001  APAP/BUTALBITAL/CAFFEINE/CODEINE
# 52296  Opioid Medications    247084530             FIORICET WITH CODEINE
# 52297  Opioid Medications    591322001  APAP/BUTALBITAL/CAFFEINE/CODEINE
#
#                                     Generic Product Name Route  \
# 52293  acetaminophen/butalbital/caffeine/codeine 300 ...  oral
# 52294  acetaminophen/butalbital/caffeine/codeine 300 ...  oral
# 52295  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
# 52296  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
# 52297  acetaminophen/butalbital/caffeine/codeine 325 ...  oral
#
#               Description Drug ID Drug Name  Package Size Unit  Dose Form  \
# 52293  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52294  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52295  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52296  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
# 52297  Opioid Medications  d03425   CODEINE           NaN   mg  30.0  NaN
#
#        MED Conversion Factor
# 52293                   0.15
# 52294                   0.15
# 52295                   0.15
# 52296                   0.15
# 52297                   0.15

# %%
opioiddrugs.columns
# Out:
# Index(['Medication List', 'NDC Code', 'Brand Name', 'Generic Product Name',
#        'Route', 'Description', 'Drug ID', 'Drug Name', 'Package Size', 'Unit',
#        'Dose', 'Form', 'MED Conversion Factor'],
#       dtype='object')

# %%
opioiddrugs['Drug Name'].unique()
# Out:
# array(['CODEINE', 'DIHYDROCODEINE', 'HYDROCODONE', 'OXYCODONE',
#        'PENTAZOCINE', 'TRAMADOL', 'OPIUM', 'BUPRENORPHINE', 'BUTORPHANOL',
#        'FENTANYL', 'HYDROMORPHONE', 'LEVORPHANOL', 'MEPERIDINE',
#        'METHADONE', 'MORPHINE', 'MORPHINE EQUIVALENT', 'OXYMORPHONE',
#        'TAPENTADOL'], dtype=object)

# %%
## convert drug name column to list
opioids = opioiddrugs['Drug Name'].unique().tolist()
## join list of strings to create regex
opioids = '|'.join(opioids)
## use str.contains to match pattern
opioids_df = drugs2[drugs2['productname'].str.contains(opioids, na=False)]

# %%
opioids
# Out:
# 'CODEINE|DIHYDROCODEINE|HYDROCODONE|OXYCODONE|PENTAZOCINE|TRAMADOL|OPIUM|BUPRENORPHINE|BUTORPHANOL|FENTANYL|HYDROMORPHONE|LEVORPHANOL|MEPERIDINE|METHADONE|MORPHINE|MORPHINE EQUIVALENT|OXYMORPHONE|TAPENTADOL'

# %%
# test to make sure we have all the opioid drugs
drugs2.loc[(drugs2.productname == 'HYDROCODON') | (drugs2.productname == 'HYDROMORP')].head()
# Out:
#       state productname  unitsreimbursed  numberofprescriptions  \
# 784      AK  HYDROCODON     1.952154e+06                39718.0
# 3387     AL  HYDROCODON     1.000201e+07               195610.0
# 6247     AR  HYDROCODON     8.757404e+06               147656.0
# 8408     AZ  HYDROCODON     1.890895e+07               330257.0
# 12067    CA  HYDROCODON     1.300894e+08              2365523.0
#
#        totalamountreimbursed  medicaidamountreimbursed  \
# 784                739899.67                 738375.47
# 3387              3950713.32                3295397.95
# 6247              2755292.77                2745125.06
# 8408              5079746.82                5054637.71
# 12067            43016748.55               41496813.82
#
#        nonmedicaidamountreimbursed
# 784                        1524.20
# 3387                     655315.37
# 6247                      10167.71
# 8408                      25109.11
# 12067                   1519934.73

# %%
drugs2.loc[drugs2.productname.str.contains('TYLENOL') == True]
# Out:
#        state productname  unitsreimbursed  numberofprescriptions  \
# 5047      AL  TYLENOL WI              0.0                    0.0
# 14447     CA  TYLENOL W/              0.0                    0.0
# 23296     CT  TYLENOL W/              0.0                    0.0
# 26499     DC  TYLENOL WI              0.0                    0.0
# 30191     DE  TYLENOL WI              0.0                    0.0
# 40589     HI  TYLENOL WI              0.0                    0.0
# 46432     ID  TYLENOL-CO              0.0                    0.0
# 50795     IL  TYLENOL W/              0.0                    0.0
# 63349     KY  TYLENOL-CO              0.0                    0.0
# 70086     MA  TYLENOL WI              0.0                    0.0
# 73956     MD  TYLENOL WI              0.0                    0.0
# 79141     MI  TYLENOL-CO              0.0                    0.0
# 82099     MN  TYLENOL-CO              0.0                    0.0
# 84925     MO  TYLENOL-CO              0.0                    0.0
# 93178     NC  TYLENOL-CO              0.0                    0.0
# 101453    NH  TYLENOL-CO              0.0                    0.0
# 106270    NJ  TYLENOL W/              0.0                    0.0
# 113926    NV  TYLENOL W/              0.0                    0.0
# 119003    NY  TYLENOL W/              0.0                    0.0
# 124252    OH  TYLENOL W/              0.0                    0.0
# 124253    OH  TYLENOL WI              0.0                    0.0
# 138920    PA  TYLENOL W/              0.0                    0.0
# 138921    PA  TYLENOL WI              0.0                    0.0
# 148535    SD  TYLENOL W/              0.0                    0.0
# 154506    TX  TYLENOL WI              0.0                    0.0
# 162934    VA  TYLENOL W/              0.0                    0.0
# 170546    WA  TYLENOL W/              0.0                    0.0
# 177777    WV  TYLENOL-CO              0.0                    0.0
#
#         totalamountreimbursed  medicaidamountreimbursed  \
# 5047                      0.0                       0.0
# 14447                     0.0                       0.0
# 23296                     0.0                       0.0
# 26499                     0.0                       0.0
# 30191                     0.0                       0.0
# 40589                     0.0                       0.0
# 46432                     0.0                       0.0
# 50795                     0.0                       0.0
# 63349                     0.0                       0.0
# 70086                     0.0                       0.0
# 73956                     0.0                       0.0
# 79141                     0.0                       0.0
# 82099                     0.0                       0.0
# 84925                     0.0                       0.0
# 93178                     0.0                       0.0
# 101453                    0.0                       0.0
# 106270                    0.0                       0.0
# 113926                    0.0                       0.0
# 119003                    0.0                       0.0
# 124252                    0.0                       0.0
# 124253                    0.0                       0.0
# 138920                    0.0                       0.0
# 138921                    0.0                       0.0
# 148535                    0.0                       0.0
# 154506                    0.0                       0.0
# 162934                    0.0                       0.0
# 170546                    0.0                       0.0
# 177777                    0.0                       0.0
#
#         nonmedicaidamountreimbursed
# 5047                            0.0
# 14447                           0.0
# 23296                           0.0
# 26499                           0.0
# 30191                           0.0
# 40589                           0.0
# 46432                           0.0
# 50795                           0.0
# 63349                           0.0
# 70086                           0.0
# 73956                           0.0
# 79141                           0.0
# 82099                           0.0
# 84925                           0.0
# 93178                           0.0
# 101453                          0.0
# 106270                          0.0
# 113926                          0.0
# 119003                          0.0
# 124252                          0.0
# 124253                          0.0
# 138920                          0.0
# 138921                          0.0
# 148535                          0.0
# 154506                          0.0
# 162934                          0.0
# 170546                          0.0
# 177777                          0.0

# %%
# it looks ike hydrocodone and hydromorphone didn't match on the opioid string
# adding our hydrocodone/hydromorphone drugs
hydros = drugs2[drugs2['productname'].str.contains('HYDROCOD', na=False)]
hydroms = drugs2[drugs2['productname'].str.contains('HYDROMOR', na=False)]

# %%
opioids_df = opioids_df.append(hydros)
opioids_df = opioids_df.append(hydroms)

# %%
opioids_df.loc[(opioids_df.productname.str.contains('HYDROCODON')) | (opioids_df.productname.str.contains('HYDROMOR'))].sample(10)
# Out:
#        state productname  unitsreimbursed  numberofprescriptions  \
# 39262     HI  HYDROCODON     3.054930e+06                58002.0
# 121755    OH  HYDROMORPH     8.310270e+05                50733.0
# 135361    PA  HYDROMORPH     8.306040e+05                35285.0
# 48584     IL  HYDROCODON     4.322964e+07               711085.0
# 80651     MN  HYDROCODON     8.558088e+06               171068.0
# 149791    TN  HYDROMORPH     1.395760e+05                 3156.0
# 61847     KY  HYDROMORPH     2.894650e+05                17198.0
# 89229     MT  HYDROMORPH     2.462015e+05                 6961.0
# 72063     MD  HYDROCODON     4.316340e+06                98733.0
# 20959     CT  HYDROCODON     3.379893e+06                69634.0
#
#         totalamountreimbursed  medicaidamountreimbursed  \
# 39262             11187950.83               11187464.70
# 121755              286004.55                 280183.01
# 135361              363925.86                 352220.62
# 48584             10578366.26               10500715.64
# 80651              2504954.00                2496040.46
# 149791               22580.92                  22547.02
# 61847               140798.33                 126831.56
# 89229               140891.17                 140382.30
# 72063               936867.31                 913481.28
# 20959              1323091.48                1312249.99
#
#         nonmedicaidamountreimbursed
# 39262                        486.13
# 121755                      5821.54
# 135361                     11705.24
# 48584                      77650.62
# 80651                       8913.54
# 149791                        33.90
# 61847                      13966.77
# 89229                        508.87
# 72063                      23386.03
# 20959                      10841.49

# %%
# checking to make sure we sorted out all the opioids ..which we're missing brand names
opioids_df.productname.unique()
# Out:
# array(['CODEINE SU', 'FENTANYL', 'FENTANYL C', 'MEPERIDINE', 'METHADONE',
#        'MORPHINE S', 'OPIUM TINC', 'OXYCODONE', 'OXYCODONE-',
#        'TRAMADOL H', 'CODEINE PH', 'FENTANYL M', 'FENTANYL P',
#        'FENTANYL R', 'FENTANYL T', 'MORPHINE P', 'OXYCODONE/',
#        'TRAMADOL 5', 'TRAMADOL A', 'TRAMADOL T', 'CODEINE-GU',
#        'FENTANYL 0', 'FENTANYL 1', 'FENTANYL 2', 'FENTANYL 3',
#        'FENTANYL 5', 'FENTANYL 6', 'FENTANYL 7', 'FENTANYL 8',
#        'TRAMADOL E', 'TRAMADOL-A', 'MORPHINE 1', 'MORPHINE 2',
#        'MORPHINE 4', 'MORPHINE 8', 'TRAMADOL/A', 'MORPHINE 5',
#        'MORPHINE 3', 'MORPHINE 0', 'TRAMADOL W', 'GG/CODEINE', 'OPIUM',
#        'HYDROCODON', 'HYDROCOD/A', 'HYDROCOD-H', 'DIHYDROCOD',
#        'HYDROCOD/I', 'HYDROCOD-C', 'HYDROMORPH', 'HYDROMOREP'],
#       dtype=object)

# %%
opioiddrugs['Brand Name'].unique()
# Out:
# array(['APAP/BUTALBITAL/CAFFEINE/CODEINE', 'FIORICET WITH CODEINE',
#        'APAP/CAFFEINE/DIHYDROCODEINE BITARTRATE', 'TREZIX',
#        'ACETAMINOPHEN-CODEINE PHOSPHATE',
#        'CAPITAL AND CODEINE SUSPENSION', 'TYLENOL WITH CODEINE #3',
#        'TYLENOL WITH CODEINE #4', 'ACETAMINOPHEN-HYDROCODONE BITARTRATE',
#        'VICODIN HP', 'XODOL', 'ZOLVIT', 'LORTAB ELIXIR', 'LORTAB',
#        'VICODIN', 'VICODIN ES', 'NORCO', 'LORTAB 10/325', 'LORCET HD',
#        'ZAMICET', 'VERDROCET', 'LORTAB 5/325', 'LORCET', 'LORTAB 7.5/325',
#        'LORCET PLUS', 'HYCET', 'PRIMLEV',
#        'ACETAMINOPHEN-OXYCODONE HYDROCHLORIDE', 'PERCOCET 10/325',
#        'ENDOCET 10/325', 'ENDOCET 2.5/325', 'PERCOCET 2.5/325', 'ROXICET',
#        'PERCOCET 5/325', 'ENDOCET 5/325', 'ENDOCET 7.5/325',
#        'PERCOCET 7.5/325', 'XARTEMIS XR', 'ACETAMINOPHEN-PENTAZOCINE',
#        'ACETAMINOPHEN-TRAMADOL HYDROCHLORIDE', 'ULTRACET',
#        'ASPIRIN/BUTALBITAL/CAFFEINE/CODEINE', 'ASCOMP WITH CODEINE',
#        'FIORINAL WITH CODEINE', 'SYNALGOS-DC',
#        'ASPIRIN/CAFFEINE/DIHYDROCODEINE',
#        'ASA/CARISOPRODOL/CODEINE PHOSPHATE', 'ASPIRIN-OXYCODONE',
#        'ENDODAN', 'BELLADONNA ALKALOIDS-OPIUM', 'BUPRENORPHINE',
#        'BUTRANS', 'BELBUCA', 'BUNAVAIL', 'BUTORPHANOL TARTRATE',
#        'CODEINE SULFATE', 'FENTORA', 'SUBSYS', 'ABSTRAL', 'FENTANYL',
#        'FENTANYL MATRIX', 'DURAGESIC-100', 'LAZANDA', 'DURAGESIC-12',
#        'FENTANYL CITRATE', 'ACTIQ', 'DURAGESIC-25', 'IONSYS',
#        'DURAGESIC-50', 'DURAGESIC-75', 'ZOHYDRO ER', 'HYSINGLA ER',
#        'HYDROCODONE-IBUPROFEN', 'REPREXAIN', 'IBUDONE', 'XYLON 10',
#        'VICOPROFEN', 'HYDROMORPHONE HYDROCHLORIDE', 'DILAUDID',
#        'DILAUDID-5', 'EXALGO', 'HYDROMORPHONE HYDROCHLORIDE ER',
#        'IBUPROFEN-OXYCODONE HYDROCHLORIDE', 'LEVORPHANOL TARTRATE',
#        'DEMEROL HCL', 'MEPERIDINE HYDROCHLORIDE',
#        'MEPERIDINE HCL-PROMETHAZINE HCL', 'DOLOPHINE',
#        'METHADONE HYDROCHLORIDE', 'METHADOSE', 'METHADOSE SUGAR-FREE',
#        'MORPHINE SULFATE', 'MORPHINE SULFATE ER', 'KADIAN', 'MS CONTIN',
#        'MORPHABOND ER', 'AVINZA', 'ARYMO ER', 'EMBEDA',
#        'NALOXONE HCL-PENTAZOCINE HCL', 'PAREGORIC', 'OPIUM DEODORIZED',
#        'OPIUM', 'OXYCODONE HYDROCHLORIDE', 'OXYCODONE HYDROCHLORIDE ER',
#        'OXYCONTIN', 'XTAMPZA ER', 'ROXICODONE', 'OXYFAST', 'OXECTA',
#        'OXAYDO', 'OXYMORPHONE HYDROCHLORIDE', 'OPANA',
#        'OXYMORPHONE HYDROCHLORIDE ER', 'OPANA ER', 'NUCYNTA',
#        'NUCYNTA ER', 'TRAMADOL HYDROCHLORIDE ER', 'CONZIP', 'ULTRAM ER',
#        'RYZOLT', 'TRAMADOL HYDROCHLORIDE', 'ULTRAM', 'RYBIX ODT'],
#       dtype=object)

# %%
# repeat filter with brand names
## convert drug name column to list
opioidbrands = opioiddrugs['Brand Name'].unique().tolist()
## join list of strings to create regex
opioidbrands = '|'.join(opioidbrands)
## use str.contains to match pattern
opioidbrands_df = drugs2[drugs2['productname'].str.contains(opioids, na=False)]

# %%
opioidbrands
# Out:
# 'APAP/BUTALBITAL/CAFFEINE/CODEINE|FIORICET WITH CODEINE|APAP/CAFFEINE/DIHYDROCODEINE BITARTRATE|TREZIX|ACETAMINOPHEN-CODEINE PHOSPHATE|CAPITAL AND CODEINE SUSPENSION|TYLENOL WITH CODEINE #3|TYLENOL WITH CODEINE #4|ACETAMINOPHEN-HYDROCODONE BITARTRATE|VICODIN HP|XODOL|ZOLVIT|LORTAB ELIXIR|LORTAB|VICODIN|VICODIN ES|NORCO|LORTAB 10/325|LORCET HD|ZAMICET|VERDROCET|LORTAB 5/325|LORCET|LORTAB 7.5/325|LORCET PLUS|HYCET|PRIMLEV|ACETAMINOPHEN-OXYCODONE HYDROCHLORIDE|PERCOCET 10/325|ENDOCET 10/325|ENDOCET 2.5/325|PERCOCET 2.5/325|ROXICET|PERCOCET 5/325|ENDOCET 5/325|ENDOCET 7.5/325|PERCOCET 7.5/325|XARTEMIS XR|ACETAMINOPHEN-PENTAZOCINE|ACETAMINOPHEN-TRAMADOL HYDROCHLORIDE|ULTRACET|ASPIRIN/BUTALBITAL/CAFFEINE/CODEINE|ASCOMP WITH CODEINE|FIORINAL WITH CODEINE|SYNALGOS-DC|ASPIRIN/CAFFEINE/DIHYDROCODEINE|ASA/CARISOPRODOL/CODEINE PHOSPHATE|ASPIRIN-OXYCODONE|ENDODAN|BELLADONNA ALKALOIDS-OPIUM|BUPRENORPHINE|BUTRANS|BELBUCA|BUNAVAIL|BUTORPHANOL TARTRATE|CODEINE SULFATE|FENTORA|SUBSYS|ABSTRAL|FENTANYL|FENTANYL MATRIX|DURAGESIC-100|LAZANDA|DURAGESIC-12|FENTANYL CITRATE|ACTIQ|DURAGESIC-25|IONSYS|DURAGESIC-50|DURAGESIC-75|ZOHYDRO ER|HYSINGLA ER|HYDROCODONE-IBUPROFEN|REPREXAIN|IBUDONE|XYLON 10|VICOPROFEN|HYDROMORPHONE HYDROCHLORIDE|DILAUDID|DILAUDID-5|EXALGO|HYDROMORPHONE HYDROCHLORIDE ER|IBUPROFEN-OXYCODONE HYDROCHLORIDE|LEVORPHANOL TARTRATE|DEMEROL HCL|MEPERIDINE HYDROCHLORIDE|MEPERIDINE HCL-PROMETHAZINE HCL|DOLOPHINE|METHADONE HYDROCHLORIDE|METHADOSE|METHADOSE SUGAR-FREE|MORPHINE SULFATE|MORPHINE SULFATE ER|KADIAN|MS CONTIN|MORPHABOND ER|AVINZA|ARYMO ER|EMBEDA|NALOXONE HCL-PENTAZOCINE HCL|PAREGORIC|OPIUM DEODORIZED|OPIUM|OXYCODONE HYDROCHLORIDE|OXYCODONE HYDROCHLORIDE ER|OXYCONTIN|XTAMPZA ER|ROXICODONE|OXYFAST|OXECTA|OXAYDO|OXYMORPHONE HYDROCHLORIDE|OPANA|OXYMORPHONE HYDROCHLORIDE ER|OPANA ER|NUCYNTA|NUCYNTA ER|TRAMADOL HYDROCHLORIDE ER|CONZIP|ULTRAM ER|RYZOLT|TRAMADOL HYDROCHLORIDE|ULTRAM|RYBIX ODT'

# %%
opioidbrands = 'BUTALBITAL|FIORICET|DIHYDROCODEINE|TREZIX|CODEINE|TYLENOL|VICODIN|XODOL|ZOLVIT|NORCO|LORTAB|LORCET|ZAMICET|VERDROCET|HYCET|PRIMLEV|PERCOCET|ENDOCET|ROXICET|XARTEMIS|PENTAZOCINE|ULTRACET|ASCOMP|FIORINAL|SYNALGOS|ENDODAN|BELLADONNA|BUPRENORPHINE|BUTRANS|BELBUCA|BUNAVAIL|BUTORPHANOL|FENTORA|SUBSYS|ABSTRAL|FENTANYL|FENTANYLDURAGESIC|LAZANDA|ACTIQ|DURAGESIC-25|IONSYS|ZOHYDRO ER|HYSINGLA|REPREXAIN|IBUDONE|XYLON|VICOPROFEN|HYDROMORPHONE|DILAUDID|EXALGO|LEVORPHANOL|DEMEROL|MEPERIDINE|DOLOPHINE|METHADONE|METHADOSE|MORPHINE SULFATE|KADIAN|MS CONTIN|MORPHABOND|AVINZA|ARYMO|EMBEDA|PENTAZOCINE|PAREGORIC|OPIUM|OXYCONTIN|XTAMPZA ER|ROXICODONE|OXYFAST|OXECTA|OXAYDO|OPANA|NUCYNTA|CONZIP|RYZOLT|TRAMADOL|ULTRAM|RYBIX'

# %%
brands_df = drugs2[drugs2['productname'].str.contains(opioidbrands, na=False)]

# %%
brands_df
# Out:
#        state productname  unitsreimbursed  numberofprescriptions  \
# 145       AK  ASCOMP WIT            0.000                    0.0
# 192       AK  BELLADONNA            0.000                    0.0
# 242       AK  BUTALBITAL        29494.000                  655.0
# 244       AK     BUTRANS          861.000                  221.0
# 366       AK  CODEINE SU            0.000                    0.0
# 437       AK     DEMEROL           59.375                   59.0
# 481       AK    DILAUDID            0.000                    0.0
# 544       AK      EMBEDA            0.000                    0.0
# 555       AK     ENDOCET        10571.000                  187.0
# 610       AK      EXALGO            0.000                    0.0
# 632       AK    FENTANYL        18670.000                 1912.0
# 633       AK  FENTANYL C        63471.850                 3092.0
# 640       AK    FIORINAL            0.000                    0.0
# 798       AK  HYSINGLA E            0.000                    0.0
# 962       AK      LORTAB         7518.000                   30.0
# 1015      AK  MEPERIDINE         1608.500                  125.0
# 1030      AK   METHADONE       150918.000                 1066.0
# 1087      AK   MS CONTIN            0.000                    0.0
# 1172      AK       NORCO           58.000                   58.0
# 1199      AK     NUCYNTA         8098.000                   93.0
# 1200      AK  NUCYNTA ER            0.000                    0.0
# 1231      AK    OPANA ER            0.000                    0.0
# 1233      AK  OPIUM TINC            0.000                    0.0
# 1264      AK   OXYCONTIN       111045.000                 1683.0
# 1293      AK    PERCOCET            0.000                    0.0
# 1487      AK     ROXICET            0.000                    0.0
# 1570      AK      SUBSYS            0.000                    0.0
# 1669      AK  TRAMADOL H       709210.500                10634.0
# 1734      AK      ULTRAM            0.000                    0.0
# 1770      AK     VICODIN            0.000                    0.0
# ...      ...         ...              ...                    ...
# 178977    WY     ENDOCET         4713.000                   51.0
# 178978    WY  ENDOCET 10         2146.000                   25.0
# 178979    WY  ENDOCET 7.            0.000                    0.0
# 178980    WY  ENDOCET TA            0.000                    0.0
# 178981    WY  ENDOCET, 5            0.000                    0.0
# 179116    WY    FENTANYL          200.000                   21.0
# 179117    WY  FENTANYL 0        25119.069                 2035.0
# 179118    WY  FENTANYL 1          399.208                  299.0
# 179119    WY  FENTANYL 2            0.000                    0.0
# 179120    WY  FENTANYL 5            0.000                    0.0
# 179121    WY  FENTANYL C          619.900                  281.0
# 179122    WY  FENTANYL M            0.000                    0.0
# 179123    WY  FENTANYL P          120.000                   12.0
# 179124    WY  FENTANYL T          303.000                   31.0
# 179257    WY  GG/CODEINE         7070.000                   46.0
# 179817    WY  MEPERIDINE            0.000                    0.0
# 179829    WY   METHADONE         9759.000                  103.0
# 180086    WY  NUCYNTA (t            0.000                    0.0
# 180087    WY  NUCYNTA ER            0.000                    0.0
# 180184    WY    OPANA ER            0.000                    0.0
# 180185    WY  OPANA ER 2            0.000                    0.0
# 180186    WY       OPIUM            0.000                    0.0
# 180215    WY   OXYCONTIN        16850.000                  276.0
# 180566    WY  ROXICET 5-            0.000                    0.0
# 180897    WY  TRAMADOL H       140212.000                 2225.0
# 180898    WY  TRAMADOL T        14800.000                  235.0
# 181053    WY     VICODIN            0.000                    0.0
# 181054    WY  VICODIN ES            0.000                    0.0
# 181055    WY  VICODIN HP            0.000                    0.0
# 181056    WY  VICODIN TA            0.000                    0.0
#
#         totalamountreimbursed  medicaidamountreimbursed  \
# 145                      0.00                      0.00
# 192                      0.00                      0.00
# 242                  43304.54                  42695.12
# 244                  79920.82                  79361.86
# 366                      0.00                      0.00
# 437                   1180.92                   1045.40
# 481                      0.00                      0.00
# 544                      0.00                      0.00
# 555                   7306.41                   7306.41
# 610                      0.00                      0.00
# 632                 157483.57                 157004.67
# 633                 233925.45                 233893.15
# 640                      0.00                      0.00
# 798                      0.00                      0.00
# 962                   3136.96                   3075.23
# 1015                  1973.84                   1556.54
# 1030                 31456.15                  31455.35
# 1087                     0.00                      0.00
# 1172                    88.98                     88.98
# 1199                 46611.86                  45047.48
# 1200                     0.00                      0.00
# 1231                     0.00                      0.00
# 1233                     0.00                      0.00
# 1264                796268.40                 791285.67
# 1293                     0.00                      0.00
# 1487                     0.00                      0.00
# 1570                     0.00                      0.00
# 1669                154734.02                 154617.18
# 1734                     0.00                      0.00
# 1770                     0.00                      0.00
# ...                       ...                       ...
# 178977                3134.13                   3134.13
# 178978                1684.53                   1684.53
# 178979                   0.00                      0.00
# 178980                   0.00                      0.00
# 178981                   0.00                      0.00
# 179116                1145.81                   1145.81
# 179117                  62.46                     62.46
# 179118                   3.05                      3.05
# 179119                   0.00                      0.00
# 179120                   0.00                      0.00
# 179121                  66.55                      2.81
# 179122                   0.00                      0.00
# 179123                1240.66                   1240.66
# 179124                4153.94                   4153.94
# 179257                 749.00                    749.00
# 179817                   0.00                      0.00
# 179829                1929.81                   1929.81
# 180086                   0.00                      0.00
# 180087                   0.00                      0.00
# 180184                   0.00                      0.00
# 180185                   0.00                      0.00
# 180186                   0.00                      0.00
# 180215              130131.54                 130131.54
# 180566                   0.00                      0.00
# 180897               13297.84                  13297.84
# 180898                1425.61                   1425.61
# 181053                   0.00                      0.00
# 181054                   0.00                      0.00
# 181055                   0.00                      0.00
# 181056                   0.00                      0.00
#
#         nonmedicaidamountreimbursed
# 145                            0.00
# 192                            0.00
# 242                          609.42
# 244                          558.96
# 366                            0.00
# 437                          135.52
# 481                            0.00
# 544                            0.00
# 555                            0.00
# 610                            0.00
# 632                          478.90
# 633                           32.30
# 640                            0.00
# 798                            0.00
# 962                           61.73
# 1015                         417.30
# 1030                           0.80
# 1087                           0.00
# 1172                           0.00
# 1199                        1564.38
# 1200                           0.00
# 1231                           0.00
# 1233                           0.00
# 1264                        4982.73
# 1293                           0.00
# 1487                           0.00
# 1570                           0.00
# 1669                         116.84
# 1734                           0.00
# 1770                           0.00
# ...                             ...
# 178977                         0.00
# 178978                         0.00
# 178979                         0.00
# 178980                         0.00
# 178981                         0.00
# 179116                         0.00
# 179117                         0.00
# 179118                         0.00
# 179119                         0.00
# 179120                         0.00
# 179121                        63.74
# 179122                         0.00
# 179123                         0.00
# 179124                         0.00
# 179257                         0.00
# 179817                         0.00
# 179829                         0.00
# 180086                         0.00
# 180087                         0.00
# 180184                         0.00
# 180185                         0.00
# 180186                         0.00
# 180215                         0.00
# 180566                         0.00
# 180897                         0.00
# 180898                         0.00
# 181053                         0.00
# 181054                         0.00
# 181055                         0.00
# 181056                         0.00
#
# [2585 rows x 7 columns]

# %%
# appending the brand name dataframe to generics
opioids_df = opioids_df.append(brands_df)
opioids_df.sample(10)
# Out:
#        state productname  unitsreimbursed  numberofprescriptions  \
# 93178     NC  TYLENOL-CO              0.0                    0.0
# 9805      AZ     VICODIN          33211.0                 1041.0
# 151614    TX   BUTRANS 5           5141.0                 1285.0
# 59098     KS    OPANA ER           3540.0                   63.0
# 108086    NM  HYDROMORPH         222712.5                12457.0
# 75466     ME   METHADONE         773405.0                 6156.0
# 8423      AZ  HYSINGLA E              0.0                    0.0
# 57089     KS  CODEINE-GU          57937.0                  426.0
# 20437     CT      EXALGO              0.0                    0.0
# 143627    SC  CODEINE SU              0.0                    0.0
#
#         totalamountreimbursed  medicaidamountreimbursed  \
# 93178                    0.00                      0.00
# 9805                 50025.14                  49899.42
# 151614              281601.86                 280787.04
# 59098                42904.91                  42778.91
# 108086               73724.00                  73668.95
# 75466               124501.89                 124148.34
# 8423                     0.00                      0.00
# 57089                 5645.18                   5084.74
# 20437                    0.00                      0.00
# 143627                   0.00                      0.00
#
#         nonmedicaidamountreimbursed
# 93178                          0.00
# 9805                         125.72
# 151614                       814.82
# 59098                        126.00
# 108086                        55.05
# 75466                        353.55
# 8423                           0.00
# 57089                        560.44
# 20437                          0.00
# 143627                         0.00

# %%
opioids_df.shape
# Out:
# (3612, 7)

# %%
# saving new opioid dataframe to csv
opioids_df.to_csv('medicaid_opioids_2016.csv')
